# %%
import pandas as pd

import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# %%
dados = pd.read_csv('C:\\Users\\silin\\OneDrive - Insper - Institudo de Ensino e Pesquisa\Aulas\\2° Semestre\\CDados\\Projeto 3\\archive\\microdados_new.csv')
# Out:
# C:\Users\silin\AppData\Local\Temp\ipykernel_13932\4082626777.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   dados = pd.read_csv('C:\\Users\\silin\\OneDrive - Insper - Institudo de Ensino e Pesquisa\Aulas\\2° Semestre\\CDados\\Projeto 3\\archive\\microdados_new.csv')

# %%
dados.head(5)
# Out:
#                                  document_id  \
# 0  a0fcb0c4-2d05-4275-bcfa-4866921d67bc-i0b0
# 1  a1697785-8504-4456-a3d6-cce7a5036d19-i0b0
# 2  a1a3b653-78d5-45a9-9b6b-4e13dfacc240-i0b0
# 3  a1c4fbba-6e3d-411e-bba2-50bde95eddfe-i0b0
# 4  a22221e1-bc9f-495f-a2c2-bf045f757194-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  75b11987b7802f89e89320a7fdc6e1f9bee562729f447a...            38.0
# 1  c2450c192236cb2375a4e1091af4e470d14c820a781279...             5.0
# 2  8be17819077d45591ca6b849c41d94c70574c4b862d3f2...            48.0
# 3  c0fc3745ec9589068a9363f58a17c595f28851334da8ac...            77.0
# 4  55f81292479fe48112840102ce043e45dc227fa1117b9e...            63.0
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0                 30357.0                          M                      4.0
# 1                 43187.0                          M                      1.0
# ...

# %%
dados.dtypes
# Out:
# document_id                                  object
# paciente_id                                  object
# paciente_idade                              float64
# paciente_dataNascimento                      object
# paciente_enumSexoBiologico                   object
# paciente_racaCor_codigo                     float64
# paciente_racaCor_valor                       object
# paciente_endereco_coIbgeMunicipio           float64
# paciente_endereco_coPais                    float64
# paciente_endereco_nmMunicipio                object
# paciente_endereco_nmPais                     object
# paciente_endereco_uf                         object
# paciente_endereco_cep                       float64
# paciente_nacionalidade_enumNacionalidade     object
# estabelecimento_valor                         int64
# estabelecimento_razaoSocial                  object
# estalecimento_noFantasia                     object
# estabelecimento_municipio_codigo            float64
# ...

# %%
dados['paciente_enumSexoBiologico'].value_counts()
# Out:
# paciente_enumSexoBiologico
# F    566765
# M    481167
# I         7
# Name: count, dtype: int64

# %%
dados_filtrados=dados[['vacina_descricao_dose','paciente_idade' , 'paciente_racaCor_valor' , 'paciente_endereco_uf' , 'vacina_categoria_nome' , 'paciente_enumSexoBiologico']]

# %%
dados_filtrados.to_csv('dados_filtrados.csv' , index=False, sep=';')
